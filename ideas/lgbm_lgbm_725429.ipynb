# %%
_positive_importances = [
    'swl_s1',
    'swl_diff1_s1',
    'swl_diff2_s2',
    'swl_s3',
    'swl_diff2_s3',
    'swl_diff1_s4',
    'swl_diff2_s4',
    'swl_diff1_s6',
    'swl_roll6_mean',
    'swl_roll12_mean',
    'swl_roll12_std',
    'inf_s1',
    'inf_diff2_s1',
    'inf_s2',
    'inf_diff1_s2',
    'inf_diff2_s2',
    'inf_s3',
    'inf_diff2_s3',
    'inf_diff1_s4',
    'inf_diff2_s5',
    'inf_s6',
    'inf_diff2_s6',
    'inf_roll6_mean',
    'inf_roll6_median',
    'inf_roll6_std',
    'inf_roll12_mean',
    'inf_roll12_median',
    'inf_roll12_std',
    'sfw_s1',
    'sfw_diff1_s1',
    'sfw_s3',
    'sfw_diff1_s3',
    'sfw_diff1_s4',
    'sfw_s5',
    'sfw_diff1_s6',
    'sfw_diff2_s6',
    'sfw_roll6_mean',
    'sfw_roll6_std',
    'sfw_roll12_mean',
    'ecpc_s1',
    'ecpc_roll12_median',
    'tototf_s1',
    'tototf_diff2_s1',
    'tototf_s2',
    'tototf_diff1_s2',
    'tototf_diff2_s3',
    'tototf_s4',
    'tototf_diff2_s4',
    'tototf_s5',
    'tototf_diff2_s5',
    'tototf_s6',
    'tototf_diff2_s6',
    'tototf_roll6_mean',
    'tototf_roll6_median',
    'tototf_roll6_std',
    'tototf_roll12_mean',
    'tototf_roll12_median',
    'tototf_roll12_std',
    'wl_1018662_s1',
    'wl_1018662_diff1_s1',
    'wl_1018662_diff2_s1',
    'wl_1018662_s2',
    'wl_1018662_diff1_s2',
    'wl_1018662_diff2_s2',
    'wl_1018662_s3',
    'wl_1018662_diff1_s3',
    'wl_1018662_diff2_s3',
    'wl_1018662_s4',
    'wl_1018662_diff1_s4',
    'wl_1018662_diff2_s4',
    'wl_1018662_s5',
    'wl_1018662_diff1_s5',
    'wl_1018662_diff2_s5',
    'wl_1018662_s6',
    'wl_1018662_diff1_s6',
    'wl_1018662_diff2_s6',
    'wl_1018662_roll6_mean',
    'wl_1018662_roll6_median',
    'wl_1018662_roll6_std',
    'wl_1018662_roll12_mean',
    'wl_1018662_roll12_median',
    'wl_1018662_roll12_std',
    'fw_1018662_s1',
    'fw_1018662_diff1_s1',
    'fw_1018662_diff2_s1',
    'fw_1018662_s2',
    'fw_1018662_diff1_s2',
    'fw_1018662_diff2_s2',
    'fw_1018662_s3',
    'fw_1018662_diff1_s3',
    'fw_1018662_diff2_s3',
    'fw_1018662_s4',
    'fw_1018662_diff1_s4',
    'fw_1018662_diff2_s4',
    'fw_1018662_s5',
    'fw_1018662_diff1_s5',
    'fw_1018662_diff2_s5',
    'fw_1018662_s6',
    'fw_1018662_diff1_s6',
    'fw_1018662_diff2_s6',
    'fw_1018662_roll6_mean',
    'fw_1018662_roll6_median',
    'fw_1018662_roll6_std',
    'fw_1018662_roll12_mean',
    'fw_1018662_roll12_median',
    'fw_1018662_roll12_std',
    'wl_1018680_s1',
    'wl_1018680_diff1_s1',
    'wl_1018680_diff2_s1',
    'wl_1018680_s2',
    'wl_1018680_diff1_s2',
    'wl_1018680_diff2_s2',
    'wl_1018680_s3',
    'wl_1018680_diff1_s3',
    'wl_1018680_diff2_s3',
    'wl_1018680_s4',
    'wl_1018680_diff1_s4',
    'wl_1018680_diff2_s4',
    'wl_1018680_s5',
    'wl_1018680_diff1_s5',
    'wl_1018680_diff2_s5',
    'wl_1018680_s6',
    'wl_1018680_diff1_s6',
    'wl_1018680_diff2_s6',
    'wl_1018680_roll6_mean',
    'wl_1018680_roll6_median',
    'wl_1018680_roll6_std',
    'wl_1018680_roll12_mean',
    'wl_1018680_roll12_median',
    'wl_1018680_roll12_std',
    'wl_1018683_s1',
    'wl_1018683_diff1_s1',
    'wl_1018683_diff2_s1',
    'wl_1018683_s2',
    'wl_1018683_diff1_s2',
    'wl_1018683_diff2_s2',
    'wl_1018683_s3',
    'wl_1018683_diff1_s3',
    'wl_1018683_diff2_s3',
    'wl_1018683_s4',
    'wl_1018683_diff1_s4',
    'wl_1018683_diff2_s4',
    'wl_1018683_s5',
    'wl_1018683_diff1_s5',
    'wl_1018683_diff2_s5',
    'wl_1018683_s6',
    'wl_1018683_diff1_s6',
    'wl_1018683_diff2_s6',
    'wl_1018683_roll6_mean',
    'wl_1018683_roll6_median',
    'wl_1018683_roll6_std',
    'wl_1018683_roll12_mean',
    'wl_1018683_roll12_median',
    'wl_1018683_roll12_std',
    'fw_1018683_s1',
    'fw_1018683_diff1_s1',
    'fw_1018683_diff2_s1',
    'fw_1018683_s2',
    'fw_1018683_diff1_s2',
    'fw_1018683_diff2_s2',
    'fw_1018683_s3',
    'fw_1018683_diff1_s3',
    'fw_1018683_diff2_s3',
    'fw_1018683_s4',
    'fw_1018683_diff1_s4',
    'fw_1018683_diff2_s4',
    'fw_1018683_s5',
    'fw_1018683_diff1_s5',
    'fw_1018683_diff2_s5',
    'fw_1018683_s6',
    'fw_1018683_diff1_s6',
    'fw_1018683_diff2_s6',
    'fw_1018683_roll6_mean',
    'fw_1018683_roll6_median',
    'fw_1018683_roll6_std',
    'fw_1018683_roll12_mean',
    'fw_1018683_roll12_median',
    'fw_1018683_roll12_std',
    'wl_1019630_s1',
    'wl_1019630_diff1_s1',
    'wl_1019630_diff2_s1',
    'wl_1019630_s2',
    'wl_1019630_diff1_s2',
    'wl_1019630_diff2_s2',
    'wl_1019630_s3',
    'wl_1019630_diff1_s3',
    'wl_1019630_diff2_s3',
    'wl_1019630_s4',
    'wl_1019630_diff1_s4',
    'wl_1019630_diff2_s4',
    'wl_1019630_s5',
    'wl_1019630_diff1_s5',
    'wl_1019630_diff2_s5',
    'wl_1019630_s6',
    'wl_1019630_diff1_s6',
    'wl_1019630_diff2_s6',
    'wl_1019630_roll6_mean',
    'wl_1019630_roll6_median',
    'wl_1019630_roll6_std',
    'wl_1019630_roll12_mean',
    'wl_1019630_roll12_median',
    'wl_1019630_roll12_std',
    'fw_1019630_s1',
    'fw_1019630_diff1_s1',
    'fw_1019630_diff2_s1',
    'fw_1019630_s2',
    'fw_1019630_diff1_s2',
    'fw_1019630_diff2_s2',
    'fw_1019630_s3',
    'fw_1019630_diff1_s3',
    'fw_1019630_diff2_s3',
    'fw_1019630_s4',
    'fw_1019630_diff1_s4',
    'fw_1019630_diff2_s4',
    'fw_1019630_s5',
    'fw_1019630_diff1_s5',
    'fw_1019630_diff2_s5',
    'fw_1019630_s6',
    'fw_1019630_diff1_s6',
    'fw_1019630_diff2_s6',
    'fw_1019630_roll6_mean',
    'fw_1019630_roll6_median',
    'fw_1019630_roll6_std',
    'fw_1019630_roll12_mean',
    'fw_1019630_roll12_median',
    'fw_1019630_roll12_std',
    'wl_1018640_s1',
    'wl_1018640_diff1_s1',
    'wl_1018640_diff2_s1',
    'wl_1018640_s2',
    'wl_1018640_diff1_s2',
    'wl_1018640_diff2_s2',
    'wl_1018640_s3',
    'wl_1018640_diff1_s3',
    'wl_1018640_diff2_s3',
    'wl_1018640_s4',
    'wl_1018640_diff2_s4',
    'wl_1018640_s5',
    'wl_1018640_diff1_s5',
    'wl_1018640_diff2_s5',
    'wl_1018640_s6',
    'wl_1018640_diff2_s6',
    'wl_1018640_roll6_mean',
    'wl_1018640_roll6_median',
    'wl_1018640_roll12_mean',
    'wl_1018640_roll12_median',
    'wl_1018640_roll12_std',
    'fw_1018640_s1',
    'fw_1018640_diff2_s1',
    'fw_1018640_s2',
    'fw_1018640_diff1_s2',
    'fw_1018640_diff2_s2',
    'fw_1018640_s3',
    'fw_1018640_diff1_s3',
    'fw_1018640_diff2_s3',
    'fw_1018640_s4',
    'fw_1018640_s5',
    'fw_1018640_s6',
    'fw_1018640_diff1_s6',
    'fw_1018640_roll6_mean',
    'fw_1018640_roll6_median',
    'fw_1018640_roll6_std',
    'fw_1018640_roll12_mean',
    'fw_1018640_roll12_median',
    'fw_1018640_roll12_std',
    'wl_1018670_diff1_s4',
    'wl_1018670_s5',
    'fw_1018670_roll6_std',
    'wl_1018675_s1',
    'wl_1018675_diff1_s5',
    'wl_1018675_diff2_s5',
    'wl_1018675_diff2_s6',
    'wl_1018675_roll12_std',
    'fw_1018675_s1',
    'fw_1018675_s5',
    'fw_1018675_roll12_mean',
    'wl_1018695_s1',
    'wl_1018695_diff1_s2',
    'wl_1018695_diff2_s6',
    'wl_1018695_roll6_std',
    'wl_1018695_roll12_mean',
    'wl_1018695_roll12_std',
    'fw_1018695_diff1_s3',
    'fw_1018695_roll12_mean',
    'fw_1018695_roll12_std',
    'wl_1018697_s1',
    'wl_1018697_diff1_s1',
    'wl_1018697_diff2_s1',
    'wl_1018697_s2',
    'wl_1018697_diff1_s2',
    'wl_1018697_diff2_s2',
    'wl_1018697_s3',
    'wl_1018697_s4',
    'wl_1018697_diff2_s4',
    'wl_1018697_diff2_s5',
    'wl_1018697_s6',
    'wl_1018697_roll6_median',
    'wl_1018697_roll12_mean',
    'wl_1018697_roll12_median',
    'wl_1018697_roll12_std',
    'fw_1018697_s1',
    'fw_1018697_diff1_s1',
    'fw_1018697_diff2_s1',
    'fw_1018697_s2',
    'fw_1018697_diff1_s2',
    'fw_1018697_diff2_s2',
    'fw_1018697_s3',
    'fw_1018697_diff1_s3',
    'fw_1018697_diff1_s4',
    'fw_1018697_diff2_s4',
    'fw_1018697_s5',
    'fw_1018697_diff1_s5',
    'fw_1018697_diff2_s5',
    'fw_1018697_roll6_median',
    'fw_1018697_roll6_std',
    'fw_1018697_roll12_mean',
    'fw_1018697_roll12_std',
    'wl_1007605_s1',
    'wl_1007605_roll12_mean',
    'wl_1007615_s1',
    'wl_1007615_s2',
    'wl_1007615_s3',
    'wl_1007615_s5',
    'wl_1007615_s6',
    'wl_1007615_roll6_std',
    'wl_1007615_roll12_mean',
    'fw_1007615_s5',
    'fw_1007615_roll12_median',
    'wl_1007617_s1',
    'wl_1007617_s2',
    'wl_1007617_s3',
    'wl_1007617_s4',
    'wl_1007617_diff2_s4',
    'fw_1007617_s1',
    'fw_1007617_s3',
    'fw_1007617_diff1_s3',
    'fw_1007617_diff2_s3',
    'fw_1007617_s4',
    'wl_1007620_diff2_s3',
    'wl_1007620_s4',
    'wl_1007620_diff2_s4',
    'wl_1007620_diff1_s5',
    'wl_1007620_diff2_s6',
    'wl_1007620_roll12_std',
    'wl_1007625_s1',
    'wl_1007625_diff2_s1',
    'wl_1007625_diff2_s2',
    'wl_1007625_diff1_s4',
    'wl_1007625_roll12_median',
    'wl_1007625_roll12_std',
    'fw_1007625_s1',
    'fw_1007625_diff1_s1',
    'fw_1007625_diff2_s1',
    'fw_1007625_s2',
    'fw_1007625_diff2_s2',
    'fw_1007625_s3',
    'fw_1007625_diff2_s3',
    'fw_1007625_diff2_s4',
    'fw_1007625_s5',
    'fw_1007625_diff1_s5',
    'fw_1007625_diff2_s5',
    'fw_1007625_s6',
    'fw_1007625_diff1_s6',
    'fw_1007625_diff2_s6',
    'fw_1007625_roll6_median',
    'fw_1007625_roll6_std',
    'fw_1007625_roll12_mean',
    'wl_1007630_diff1_s1',
    'wl_1007633_s1',
    'wl_1007633_diff2_s3',
    'wl_1007633_diff1_s4',
    'wl_1007633_roll6_std',
    'wl_1007634_s1',
    'wl_1007634_diff1_s1',
    'wl_1007634_diff2_s1',
    'wl_1007634_diff1_s3',
    'wl_1007634_s4',
    'wl_1007634_diff1_s4',
    'wl_1007634_diff1_s6',
    'wl_1007634_roll6_mean',
    'wl_1007634_roll12_mean',
    'wl_1007634_roll12_std',
    'wl_1007635_s1',
    'wl_1007635_diff2_s1',
    'wl_1007635_diff2_s3',
    'fw_1007635_s1',
    'fw_1007635_diff1_s1',
    'fw_1007635_s2',
    'fw_1007635_diff2_s2',
    'fw_1007635_diff1_s3',
    'fw_1007635_diff2_s3',
    'fw_1007635_diff2_s4',
    'fw_1007635_s5',
    'fw_1007635_diff2_s5',
    'fw_1007635_diff2_s6',
    'fw_1007635_roll6_mean',
    'fw_1007635_roll12_mean',
    'fw_1007635_roll12_median',
    'fw_1007635_roll12_std',
    'wl_1007639_s1',
    'wl_1007639_diff2_s5',
    'wl_1007639_diff1_s6',
    'wl_1007639_roll6_mean',
    'wl_1007639_roll6_median',
    'wl_1007639_roll12_std',
    'fw_1007640_s1',
    'fw_1007640_diff1_s1',
    'fw_1007640_diff2_s1',
    'fw_1007640_diff2_s3',
    'fw_1007640_diff1_s4',
    'fw_1007640_diff2_s4',
    'fw_1007640_roll6_mean',
    'fw_1007640_roll12_std',
    'wl_1007641_s2',
    'wl_1007641_s3',
    'wl_1007641_roll6_mean',
    'wl_1007641_roll6_std',
    'wl_1007645_s1',
    'wl_1007645_diff2_s6',
    'wl_1007645_roll6_std',
    'wl_1007645_roll12_mean',
    'fw_1007645_diff1_s5',
    'fw_1007645_roll12_std',
    'wl_1007649_diff2_s1',
    'wl_1007649_s3',
    'wl_1007649_diff1_s3',
    'wl_1007649_diff2_s4',
    'wl_1007649_s5',
    'wl_1007649_s6',
    'wl_1007649_diff1_s6',
    'wl_1007649_roll12_median',
    'wl_1007649_roll12_std',
    'wl_1007650_s1',
    'wl_1007650_diff1_s1',
    'wl_1007650_diff2_s1',
    'wl_1007650_s2',
    'wl_1007650_s3',
    'wl_1007650_diff2_s6',
    'wl_1007650_roll6_mean',
    'wl_1007650_roll12_mean',
    'fw_1007650_s1',
    'fw_1007650_s2',
    'fw_1007650_s5',
    'fw_1007650_diff1_s5',
    'wl_1007655_s1',
    'wl_1007655_s4',
    'wl_1007655_s5',
    'wl_1007655_s6',
    'wl_1007655_roll6_median',
    'wl_1007655_roll12_mean',
    'wl_1007655_roll12_std',
    'fw_1007655_diff2_s1',
    'fw_1007655_s3',
    'fw_1007655_s6',
    'fw_1007655_roll12_median',
    'wl_1007660_s3',
    'wl_1007660_roll6_std',
    'wl_1007660_roll12_std',
    'fw_1007660_s1',
    'fw_1007660_diff2_s1',
    'fw_1007660_s2',
    'fw_1007660_diff1_s2',
    'fw_1007660_diff1_s3',
    'fw_1007660_diff2_s3',
    'fw_1007660_s4',
    'fw_1007660_diff1_s4',
    'fw_1007660_diff2_s4',
    'fw_1007660_diff1_s5',
    'fw_1007660_diff2_s5',
    'fw_1007660_s6',
    'fw_1007660_diff1_s6',
    'fw_1007660_diff2_s6',
    'fw_1007660_roll6_std',
    'fw_1007660_roll12_mean',
    'fw_1007660_roll12_std',
    'wl_1007662_s1',
    'wl_1007662_s5',
    'wl_1007662_roll6_std',
    'wl_1007664_s1',
    'wl_1007664_diff1_s1',
    'wl_1007664_s2',
    'wl_1007664_diff2_s2',
    'wl_1007664_s3',
    'wl_1007664_s4',
    'wl_1007664_diff1_s4',
    'wl_1007664_diff2_s4',
    'wl_1007664_diff2_s6',
    'wl_1007664_roll6_median',
    'wl_1007664_roll6_std',
    'wl_1007664_roll12_std',
    'wl_1007680_s1',
    'wl_1007680_roll6_median',
    'wl_1007680_roll6_std',
    'wl_1007680_roll12_median',
    'wl_1007680_roll12_std',
    'fw_1007680_diff2_s1',
    'fw_1007680_diff1_s2',
    'fw_1007680_diff1_s4',
    'fw_1007680_diff1_s6',
    'fw_1007680_roll12_median',
    'fw_1007680_roll12_std',
    'wl_1007685_s1',
    'wl_1007685_s2',
    'wl_1007685_s4',
    'wl_1007685_s5',
    'wl_1007685_s6',
    'wl_1007685_diff2_s6',
    'wl_1007685_roll6_std',
    'wl_1007685_roll12_mean',
    'wl_1007685_roll12_std',
    'fw_1007685_s1',
    'fw_1007685_diff1_s1',
    'fw_1007685_diff2_s1',
    'fw_1007685_s2',
    'fw_1007685_diff1_s2',
    'fw_1007685_diff2_s2',
    'fw_1007685_s3',
    'fw_1007685_diff1_s3',
    'fw_1007685_diff2_s3',
    'fw_1007685_diff1_s4',
    'fw_1007685_s5',
    'fw_1007685_diff1_s5',
    'fw_1007685_diff2_s5',
    'fw_1007685_diff1_s6',
    'fw_1007685_roll6_mean',
    'fw_1007685_roll6_median',
    'fw_1007685_roll6_std',
    'fw_1007685_roll12_mean',
    'fw_1007685_roll12_std',
    'wl_1007690_s1',
    'wl_1007690_s3',
    'wl_1007690_s5',
    'wl_1007690_s6',
    'wl_1007690_roll6_mean',
    'fw_1007690_s1',
    'fw_1007690_diff2_s2',
    'fw_1007690_diff1_s6',
    'fw_1007690_roll6_std',
    'fw_1007690_roll12_std',
    'wl_1013620_s3',
    'wl_1013620_diff2_s5',
    'wl_1013620_s6',
    'wl_1013620_roll6_median',
    'wl_1013620_roll12_mean',
    'wl_1013620_roll12_std',
    'wl_1013652_s2',
    'wl_1013652_diff1_s3',
    'wl_1013652_s6',
    'wl_1013652_roll6_median',
    'wl_1013652_roll12_mean',
    'wl_1013652_roll12_median',
    'wl_1013655_s1',
    'wl_1013655_s4',
    'wl_1013655_roll12_std',
    'fw_1013655_s1',
    'fw_1013655_roll12_std',
    'wl_1015630_s1',
    'wl_1015630_diff1_s1',
    'wl_1015630_diff1_s2',
    'wl_1015630_diff2_s2',
    'wl_1015630_s5',
    'wl_1015630_s6',
    'wl_1015630_roll12_mean',
    'wl_1015630_roll12_std',
    'wl_1015640_s1',
    'wl_1015640_diff1_s1',
    'wl_1015640_diff2_s1',
    'wl_1015640_s2',
    'wl_1015640_diff1_s2',
    'wl_1015640_diff2_s2',
    'wl_1015640_s5',
    'wl_1015640_diff2_s5',
    'wl_1015640_s6',
    'wl_1015640_roll6_std',
    'wl_1015640_roll12_median',
    'wl_1015640_roll12_std',
    'wl_1015644_s1',
    'wl_1015644_diff2_s3',
    'wl_1015644_diff1_s4',
    'wl_1015644_diff1_s5',
    'wl_1015644_s6',
    'wl_1015644_diff1_s6',
    'wl_1015644_diff2_s6',
    'wl_1015644_roll6_mean',
    'wl_1015644_roll6_median',
    'wl_1015644_roll6_std',
    'wl_1015644_roll12_mean',
    'fw_1015644_diff1_s4',
    'fw_1015644_s5',
    'wl_1015645_s1',
    'wl_1015645_s2',
    'wl_1015645_s3',
    'wl_1015645_diff2_s3',
    'wl_1015645_s6',
    'wl_1015645_roll6_median',
    'wl_1015645_roll6_std',
    'wl_1015645_roll12_mean',
    'wl_1015645_roll12_median',
    'fw_1015645_diff1_s1',
    'fw_1015645_diff1_s2',
    'fw_1015645_diff2_s2',
    'fw_1015645_s3',
    'fw_1015645_diff1_s5',
    'fw_1015645_diff2_s5',
    'fw_1015645_s6',
    'fw_1015645_diff1_s6',
    'fw_1015645_diff2_s6',
    'fw_1015645_roll6_std',
    'fw_1015645_roll12_median',
    'wl_1015680_s1',
    'wl_1015680_s2',
    'wl_1015680_s3',
    'wl_1015680_diff1_s3',
    'wl_1015680_diff2_s3',
    'wl_1015680_s4',
    'wl_1015680_s5',
    'wl_1015680_s6',
    'wl_1015680_roll6_mean',
    'wl_1015680_roll12_mean',
    'wl_1015680_roll12_median',
    'wl_1015680_roll12_std',
    'wl_1016607_roll6_std',
    'wl_1016607_roll12_mean',
    'wl_1016607_roll12_std',
    'fw_1016607_roll12_mean',
    'wl_1016650_diff1_s1',
    'wl_1016650_diff2_s1',
    'wl_1016650_diff1_s2',
    'wl_1016650_diff2_s2',
    'wl_1016650_roll6_std',
    'fw_1016650_s1',
    'fw_1016650_diff2_s1',
    'fw_1016650_diff1_s2',
    'wl_1016655_diff2_s1',
    'wl_1016655_diff1_s2',
    'wl_1016655_diff2_s2',
    'wl_1016655_s3',
    'wl_1016655_diff1_s3',
    'wl_1016655_roll6_mean',
    'wl_1016655_roll6_std',
    'wl_1016655_roll12_mean',
    'fw_1016660_diff2_s4',
    'fw_1016660_roll12_std',
    'wl_1016670_s1',
    'wl_1016670_diff2_s1',
    'wl_1016670_s2',
    'wl_1016670_diff1_s2',
    'wl_1016670_diff2_s2',
    'wl_1016670_roll6_mean',
    'wl_1016670_roll6_std',
    'wl_1016695_s1',
    'wl_1016695_diff1_s1',
    'wl_1016695_s2',
    'wl_1016695_s3',
    'wl_1016695_s5',
    'wl_1016695_s6',
    'wl_1016695_roll6_mean',
    'wl_1016695_roll6_median',
    'wl_1016695_roll12_mean',
    'wl_1016695_roll12_median',
    'wl_1017690_s1',
    'wl_1017690_diff1_s1',
    'wl_1017690_diff2_s1',
    'wl_1017690_s2',
    'wl_1017690_s6',
    'wl_1017690_roll6_mean',
    'wl_1017690_roll12_mean',
    'wl_1017690_roll12_std',
    'wl_1018610_s1',
    'wl_1018610_s2',
    'wl_1018610_s3',
    'wl_1018610_diff2_s3',
    'wl_1018610_s4',
    'wl_1018610_s5',
    'wl_1018610_diff2_s5',
    'wl_1018610_s6',
    'wl_1018610_diff2_s6',
    'wl_1018610_roll6_mean',
    'wl_1018610_roll6_median',
    'wl_1018610_roll6_std',
    'wl_1018610_roll12_mean',
    'wl_1018610_roll12_median',
    'fw_1018610_s1',
    'fw_1018610_s2',
    'fw_1018610_s3',
    'fw_1018610_diff1_s3',
    'fw_1018610_s4',
    'fw_1018610_s5',
    'fw_1018610_diff1_s5',
    'fw_1018610_s6',
    'fw_1018610_diff1_s6',
    'fw_1018610_diff2_s6',
    'fw_1018610_roll6_mean',
    'fw_1018610_roll6_median',
    'fw_1018610_roll12_mean',
    'fw_1018610_roll12_median',
    'wl_1018620_s1',
    'wl_1018620_roll6_std',
    'wl_1018620_roll12_mean',
    'fw_1018620_s1',
    'fw_1018620_roll6_std',
    'wl_1018623_s1',
    'wl_1018623_diff2_s1',
    'wl_1018623_s2',
    'wl_1018623_diff1_s2',
    'wl_1018623_s3',
    'wl_1018623_diff2_s3',
    'wl_1018623_s4',
    'wl_1018623_diff1_s4',
    'wl_1018623_s5',
    'wl_1018623_diff2_s5',
    'wl_1018623_s6',
    'wl_1018623_diff1_s6',
    'wl_1018623_diff2_s6',
    'wl_1018623_roll6_mean',
    'wl_1018623_roll6_std',
    'wl_1018623_roll12_mean',
    'wl_1018623_roll12_median',
    'wl_1018623_roll12_std',
    'fw_1018623_roll12_std',
    'wl_1018625_s1',
    'wl_1018625_s2',
    'wl_1018625_diff2_s4',
    'wl_1018625_roll6_std',
    'wl_1018625_roll12_mean',
    'fw_1018625_diff1_s1',
    'fw_1018625_diff2_s1',
    'fw_1018625_s2',
    'fw_1018625_diff2_s6',
    'fw_1018625_roll6_median',
    'fw_1018625_roll6_std',
    'wl_1018630_s1',
    'wl_1018630_s2',
    'wl_1018630_roll6_mean',
    'fw_1018630_s1',
    'fw_1018630_diff1_s1',
    'fw_1018630_diff2_s2',
    'fw_1018630_diff1_s6',
    'fw_1018630_roll6_std',
    'wl_1018635_s1',
    'wl_1018635_s6',
    'wl_1018635_roll6_std',
    'wl_1018635_roll12_median',
    'fw_1018635_diff2_s3',
    'fw_1018635_diff1_s6',
    'fw_1018635_diff2_s6',
    'fw_1018635_roll6_std',
    'fw_1018635_roll12_std',
    'wl_1018650_s1',
    'wl_1018650_s2',
    'wl_1018650_s3',
    'wl_1018650_s4',
    'wl_1018650_diff2_s6',
    'wl_1018650_roll6_mean',
    'wl_1018650_roll6_median',
    'wl_1018650_roll12_mean',
    'wl_1018650_roll12_std',
    'fw_1018650_s1',
    'fw_1018650_diff1_s4',
    'fw_1018650_diff2_s4',
    'fw_1018650_roll6_std',
    'fw_1018650_roll12_mean',
    'fw_1018650_roll12_std',
    'wl_1018665_s1',
    'fw_1018665_s3',
    'fw_1018665_diff2_s4',
    'fw_1018665_roll12_std',
    'wl_1018690_s1',
    'wl_1018690_roll6_median',
    'fw_1018690_s1',
    'fw_1018690_roll6_mean',
    'wl_1018693_s1',
    'wl_1018693_diff1_s1',
    'wl_1018693_diff2_s1',
    'wl_1018693_diff1_s4',
    'wl_1018693_roll6_std',
    'wl_1018693_roll12_mean',
    'fw_1018693_diff1_s1',
    'fw_1018693_diff2_s1',
    'fw_1018693_s4',
    'fw_1018693_diff2_s4',
    'fw_1018693_diff2_s5',
    'fw_1018693_s6',
    'fw_1018693_diff2_s6',
    'fw_1018693_roll6_mean',
    'fw_1018693_roll6_std',
    'fw_1018693_roll12_mean',
    'fw_1018693_roll12_median',
    'fw_1018693_roll12_std',
    'wl_1019620_s2',
    'wl_1019620_s5',
    'wl_1019620_roll6_mean',
    'wl_1019620_roll6_median',
    'wl_1019620_roll6_std',
    'wl_1019620_roll12_std',
    'wl_1019635_s1',
    'wl_1019635_s2',
    'wl_1019635_s4',
    'wl_1019635_diff1_s4',
    'wl_1019635_s5',
    'wl_1019635_diff1_s5',
    'wl_1019635_s6',
    'wl_1019635_diff2_s6',
    'wl_1019635_roll6_mean',
    'wl_1019635_roll6_median',
    'wl_1019635_roll12_mean',
    'wl_1019635_roll12_median',
    'wl_1019675_s1',
    'wl_1019675_diff1_s1',
    'wl_1019675_diff2_s1',
    'wl_1019675_s2',
    'wl_1019675_diff1_s2',
    'wl_1019675_diff2_s2',
    'wl_1019675_s3',
    'wl_1019675_diff1_s3',
    'wl_1019675_diff2_s3',
    'wl_1019675_s4',
    'wl_1019675_diff1_s4',
    'wl_1019675_diff2_s4',
    'wl_1019675_s5',
    'wl_1019675_diff1_s5',
    'wl_1019675_diff2_s5',
    'wl_1019675_s6',
    'wl_1019675_diff1_s6',
    'wl_1019675_diff2_s6',
    'wl_1019675_roll6_mean',
    'wl_1019675_roll6_median',
    'wl_1019675_roll6_std',
    'wl_1019675_roll12_mean',
    'wl_1019675_roll12_median',
    'wl_1019675_roll12_std',
    'wl_1021650_roll12_median',
    'fw_1021650_s1',
    'fw_1021650_diff2_s2',
    'fw_1021650_s5',
    'fw_1021650_diff1_s5',
    'fw_1021650_roll6_median',
    'fw_1021650_roll12_std',
    'wl_1021670_s1',
    'wl_1021670_diff1_s1',
    'wl_1021670_diff2_s1',
    'wl_1021670_diff2_s4',
    'wl_1021670_diff1_s5',
    'wl_1021670_s6',
    'wl_1021670_diff1_s6',
    'wl_1021670_diff2_s6',
    'wl_1021670_roll6_std',
    'wl_1021670_roll12_median',
    'wl_1021680_s1',
    'wl_1021680_diff2_s5',
    'fw_1021680_diff2_s5',
    'fw_1021680_roll6_median',
    'wl_1022640_s1',
    'wl_1022640_diff1_s2',
    'wl_1022640_diff2_s3',
    'wl_1022640_s4',
    'wl_1022640_diff1_s4',
    'wl_1022640_diff1_s5',
    'wl_1022640_s6',
    'wl_1022640_diff1_s6',
    'wl_1022640_roll6_mean',
    'wl_1022640_roll12_mean',
    'wl_1022640_roll12_std',
    'fw_1022640_diff1_s1',
    'fw_1022640_diff2_s1',
    'fw_1022640_diff2_s3',
    'fw_1022640_diff1_s5',
    'fw_1022640_roll6_mean',
    'fw_1022640_roll12_mean',
    'wl_1022648_s1',
    'wl_1022648_roll6_std',
    'fw_1022648_roll12_median',
    'wl_1022650_s1',
    'wl_1022650_s2',
    'wl_1022650_s4',
    'wl_1022650_roll6_mean',
    'wl_1022650_roll12_mean',
    'fw_1022650_diff2_s6',
    'wl_1022655_s1',
    'wl_1022655_diff2_s1',
    'wl_1022655_diff1_s2',
    'wl_1022655_diff2_s3',
    'wl_1022655_diff1_s4',
    'wl_1022655_diff1_s6',
    'wl_1022655_diff2_s6',
    'fw_1022655_diff1_s6',
    'wl_1022670_diff2_s1',
    'wl_1022670_diff2_s2',
    'wl_1022670_diff2_s3',
    'wl_1022670_roll12_mean',
    'fw_1022670_s2',
    'fw_1022670_roll6_mean',
    'wl_1022680_s1',
    'wl_1022680_diff2_s2',
    'wl_1022680_s5',
    'wl_1022680_diff2_s6',
    'wl_1022680_roll6_std',
    'wl_1022680_roll12_std',
    'fw_1022680_diff1_s2',
    'fw_1022680_diff2_s3',
    'fw_1022680_diff2_s6',
    'wl_1023640_diff1_s1',
    'wl_1023640_diff2_s2',
    'wl_1023640_diff1_s4',
    'wl_1023640_diff2_s6',
    'wl_1023660_s1',
    'wl_1023660_roll12_mean',
    'wl_1023660_roll12_median',
    'wl_1023660_roll12_std',
    'fw_1023660_s1',
    'fw_1023660_roll12_std',
    'wl_1023662_s1',
    'wl_1023662_diff2_s1',
    'wl_1023662_diff1_s2',
    'wl_1023662_diff2_s2',
    'wl_1023662_s3',
    'wl_1023662_diff1_s3',
    'wl_1023662_s5',
    'wl_1023662_roll12_mean',
    'wl_1023662_roll12_median',
    'wl_1023662_roll12_std',
    'wl_1023670_s1',
    'wl_1023670_diff1_s1',
    'wl_1023670_diff2_s1',
    'wl_1023670_s2',
    'wl_1023670_diff1_s2',
    'wl_1023670_diff2_s2',
    'wl_1023670_s3',
    'wl_1023670_diff1_s3',
    'wl_1023670_diff2_s3',
    'wl_1023670_s4',
    'wl_1023670_diff1_s4',
    'wl_1023670_diff2_s4',
    'wl_1023670_s5',
    'wl_1023670_diff1_s5',
    'wl_1023670_diff2_s5',
    'wl_1023670_s6',
    'wl_1023670_diff1_s6',
    'wl_1023670_diff2_s6',
    'wl_1023670_roll6_mean',
    'wl_1023670_roll6_median',
    'wl_1023670_roll6_std',
    'wl_1023670_roll12_mean',
    'wl_1023670_roll12_median',
    'wl_1023670_roll12_std',
    'fw_1023670_s1',
    'fw_1023670_diff1_s1',
    'fw_1023670_diff2_s3',
    'fw_1023670_s4',
    'fw_1023670_diff1_s4',
    'fw_1023670_s6',
    'fw_1023670_diff1_s6',
    'fw_1023670_roll6_mean',
    'fw_1023670_roll6_median',
    'fw_1023670_roll6_std',
    'fw_1023670_roll12_mean',
    'fw_1023670_roll12_std',
    'wl_1023680_s1',
    'wl_1023680_diff1_s1',
    'wl_1023680_diff2_s1',
    'wl_1023680_s2',
    'wl_1023680_diff1_s2',
    'wl_1023680_diff2_s2',
    'wl_1023680_s3',
    'wl_1023680_diff1_s3',
    'wl_1023680_diff2_s3',
    'wl_1023680_diff1_s4',
    'wl_1023680_diff2_s4',
    'wl_1023680_s5',
    'wl_1023680_diff1_s5',
    'wl_1023680_diff2_s5',
    'wl_1023680_s6',
    'wl_1023680_diff1_s6',
    'wl_1023680_diff2_s6',
    'wl_1023680_roll6_std',
    'wl_1023680_roll12_mean',
    'wl_1023680_roll12_median',
    'wl_1101605_s4',
    'wl_1101605_s5',
    'wl_1101605_s6',
    'wl_1101605_roll6_std',
    'fw_1101605_roll6_std',
    'wl_1101610_s1',
    'wl_1101610_s2',
    'wl_1101610_s3',
    'wl_1101610_s6',
    'wl_1101610_roll6_mean',
    'wl_1101610_roll12_mean',
    'wl_1101610_roll12_median',
    'wl_1101610_roll12_std',
    'fw_1101610_diff2_s3',
    'fw_1101610_diff2_s5',
    'fw_1101610_roll6_mean',
    'fw_1101610_roll12_std',
    'fw_1101620_roll6_std',
    'wl_1101635_s1',
    'wl_1101635_s2',
    'wl_1101635_s3',
    'wl_1101635_diff2_s3',
    'wl_1101635_s4',
    'wl_1101635_s5',
    'wl_1101635_s6',
    'wl_1101635_diff1_s6',
    'wl_1101635_roll6_mean',
    'wl_1101635_roll6_median',
    'wl_1101635_roll6_std',
    'wl_1101635_roll12_mean',
    'wl_1101635_roll12_median',
    'wl_1101635_roll12_std',
    'fw_1101635_s1',
    'fw_1101635_diff1_s1',
    'fw_1101635_diff2_s1',
    'fw_1101635_s2',
    'fw_1101635_diff1_s2',
    'fw_1101635_diff2_s2',
    'fw_1101635_s3',
    'fw_1101635_diff1_s3',
    'fw_1101635_s4',
    'fw_1101635_diff2_s5',
    'fw_1101635_s6',
    'fw_1101635_diff1_s6',
    'fw_1101635_diff2_s6',
    'fw_1101635_roll6_median',
    'fw_1101635_roll6_std',
    'fw_1101635_roll12_std',
    'wl_1101645_s1',
    'wl_1101645_roll12_mean',
    'fw_1101645_diff2_s1',
    'fw_1101645_diff1_s2',
    'wl_1101650_s1',
    'wl_1101650_s2',
    'wl_1101650_s5',
    'wl_1101650_s6',
    'wl_1101650_diff2_s6',
    'wl_1101650_roll6_std',
    'wl_1101650_roll12_mean',
    'wl_1101650_roll12_std',
    'fw_1101650_diff1_s1',
    'fw_1101650_diff2_s5',
    'fw_1101650_diff2_s6',
    'fw_1101650_roll6_std',
    'fw_1101650_roll12_mean',
    'fw_1101650_roll12_std',
    'wl_1101663_diff2_s4',
    'wl_1101663_s5',
    'wl_1101663_roll6_std',
    'wl_1101663_roll12_median',
    'fw_1101663_s3',
    'wl_1101665_s1',
    'wl_1101665_s4',
    'wl_1101665_s6',
    'wl_1101665_diff2_s6',
    'wl_1101665_roll12_median',
    'fw_1101665_s1',
    'fw_1101665_diff2_s1',
    'fw_1101665_roll6_median',
    'fw_1101665_roll12_std',
    'wl_1101670_roll6_mean',
    'wl_1101670_roll6_std',
    'wl_1101670_roll12_std',
    'fw_1101670_diff1_s1',
    'fw_1101670_diff2_s1',
    'fw_1101670_diff2_s2',
    'fw_1101670_s3',
    'fw_1101670_diff1_s3',
    'fw_1101670_diff2_s3',
    'fw_1101670_diff1_s4',
    'fw_1101670_diff2_s4',
    'fw_1101670_s5',
    'fw_1101670_diff1_s5',
    'fw_1101670_diff2_s5',
    'fw_1101670_diff1_s6',
    'fw_1101670_diff2_s6',
    'fw_1101670_roll6_std',
    'fw_1101670_roll12_std',
    'wl_1101680_s1',
    'wl_1101680_diff1_s3',
    'wl_1101680_roll6_mean',
    'fw_1101680_s1',
    'fw_1101680_diff1_s1',
    'fw_1101680_diff2_s1',
    'fw_1101680_s2',
    'fw_1101680_diff2_s2',
    'fw_1101680_diff2_s3',
    'fw_1101680_s4',
    'fw_1101680_diff1_s4',
    'fw_1101680_diff2_s4',
    'fw_1101680_s5',
    'fw_1101680_diff1_s5',
    'fw_1101680_diff2_s5',
    'fw_1101680_s6',
    'fw_1101680_diff1_s6',
    'fw_1101680_diff2_s6',
    'fw_1101680_roll6_mean',
    'fw_1101680_roll6_median',
    'fw_1101680_roll6_std',
    'fw_1101680_roll12_std',
    'wl_1101695_s2',
    'wl_1101695_s3',
    'wl_1101695_s4',
    'wl_1101695_diff2_s4',
    'wl_1101695_s5',
    'wl_1101695_diff2_s5',
    'wl_1101695_s6',
    'wl_1101695_diff1_s6',
    'wl_1101695_roll6_std',
    'wl_1101696_s1',
    'wl_1101696_diff1_s1',
    'wl_1101696_diff2_s1',
    'wl_1101696_s2',
    'wl_1101696_s3',
    'wl_1101696_diff1_s6',
    'wl_1101696_roll6_std',
    'wl_1101696_roll12_mean',
    'wl_1101696_roll12_std',
    'tide_level_DT_0032_s1',
    'tide_level_DT_0032_diff2_s1',
    'tide_level_DT_0032_s2',
    'tide_level_DT_0032_diff1_s2',
    'tide_level_DT_0032_diff2_s2',
    'tide_level_DT_0032_s3',
    'tide_level_DT_0032_diff1_s3',
    'tide_level_DT_0032_diff2_s3',
    'tide_level_DT_0032_s4',
    'tide_level_DT_0032_diff1_s4',
    'tide_level_DT_0032_diff2_s4',
    'tide_level_DT_0032_s5',
    'tide_level_DT_0032_diff1_s5',
    'tide_level_DT_0032_diff2_s5',
    'tide_level_DT_0032_s6',
    'tide_level_DT_0032_diff1_s6',
    'tide_level_DT_0032_diff2_s6',
    'tide_level_DT_0032_roll6_mean',
    'tide_level_DT_0032_roll6_median',
    'tide_level_DT_0032_roll6_std',
    'tide_level_DT_0032_roll12_mean',
    'tide_level_DT_0032_roll12_median',
    'tide_level_DT_0032_roll12_std',
    'tide_level_DT_0044_s1',
    'tide_level_DT_0044_diff1_s1',
    'tide_level_DT_0044_diff2_s1',
    'tide_level_DT_0044_s2',
    'tide_level_DT_0044_diff1_s2',
    'tide_level_DT_0044_diff2_s2',
    'tide_level_DT_0044_s3',
    'tide_level_DT_0044_diff1_s3',
    'tide_level_DT_0044_diff2_s3',
    'tide_level_DT_0044_s4',
    'tide_level_DT_0044_s5',
    'tide_level_DT_0044_diff2_s5',
    'tide_level_DT_0044_s6',
    'tide_level_DT_0044_diff1_s6',
    'tide_level_DT_0044_diff2_s6',
    'tide_level_DT_0044_roll6_std',
    'tide_level_DT_0044_roll12_mean',
    'tide_level_DT_0044_roll12_median',
    'tide_level_DT_0044_roll12_std',
    'tide_level_DT_0058_s1',
    'tide_level_DT_0058_diff1_s1',
    'tide_level_DT_0058_diff2_s1',
    'tide_level_DT_0058_s2',
    'tide_level_DT_0058_diff1_s2',
    'tide_level_DT_0058_diff2_s2',
    'tide_level_DT_0058_s3',
    'tide_level_DT_0058_diff1_s3',
    'tide_level_DT_0058_diff2_s3',
    'tide_level_DT_0058_s4',
    'tide_level_DT_0058_diff1_s4',
    'tide_level_DT_0058_diff2_s4',
    'tide_level_DT_0058_s5',
    'tide_level_DT_0058_diff2_s5',
    'tide_level_DT_0058_s6',
    'tide_level_DT_0058_diff2_s6',
    'tide_level_DT_0058_roll6_mean',
    'tide_level_DT_0058_roll6_std',
    'tide_level_DT_0058_roll12_mean',
    'tide_level_DT_0058_roll12_median',
    'tide_level_DT_0058_roll12_std',
    'rf_10184100_roll6_std',
    'rf_10184100_roll12_std',
    'rf_10184110_roll6_std',
    'rf_10184140_s1',
    'rf_10184140_roll6_std',
    'rf_10184080_roll12_std',
    'rf_10184190_roll6_std',
    'rf_10184200_roll12_mean',
    'rf_10184200_roll12_std',
    'rf_10194030_roll6_std',
    'rf_10194030_roll12_std',
    'rf_10064030_diff2_s6',
    'rf_10064030_roll6_std',
    'rf_10074010_roll6_std',
    'rf_10074010_roll12_std',
    'rf_10074030_roll12_std',
    'rf_10074040_roll12_std',
    'rf_10074060_roll6_std',
    'rf_10074060_roll12_std',
    'rf_10074080_roll6_std',
    'rf_10074090_roll6_std',
    'rf_10074100_roll12_std',
    'rf_10074120_roll12_std',
    'rf_10134020_roll12_std',
    'rf_10134030_roll12_std',
    'rf_10134045_roll6_std',
    'rf_10134045_roll12_std',
    'rf_10154010_roll12_std',
    'rf_10154020_roll12_std',
    'rf_10154030_roll6_mean',
    'rf_10154030_roll12_std',
    'rf_10154035_roll6_std',
    'rf_10154035_roll12_std',
    'rf_10164010_roll6_std',
    'rf_10164020_roll6_std',
    'rf_10164030_roll6_std',
    'rf_10164030_roll12_std',
    'rf_10164040_roll12_std',
    'rf_10164050_roll12_std',
    'rf_10164060_roll12_median',
    'rf_10164060_roll12_std',
    'rf_10164070_roll12_std',
    'rf_10164075_roll6_std',
    'rf_10164075_roll12_std',
    'rf_10164080_roll6_std',
    'rf_10164080_roll12_std',
    'rf_10184010_roll6_std',
    'rf_10184020_roll12_std',
    'rf_10184040_s1',
    'rf_10184040_roll12_mean',
    'rf_10184040_roll12_std',
    'rf_10184060_roll6_mean',
    'rf_10184060_roll6_std',
    'rf_10184060_roll12_mean',
    'rf_10184060_roll12_median',
    'rf_10184060_roll12_std',
    'rf_10184125_roll12_std',
    'rf_10184130_roll6_mean',
    'rf_10184130_roll6_median',
    'rf_10184150_roll6_std',
    'rf_10184160_roll6_std',
    'rf_10184160_roll12_std',
    'rf_10184170_roll12_std',
    'rf_10184210_roll6_std',
    'rf_10184210_roll12_median',
    'rf_10184220_roll12_std',
    'rf_10184230_roll6_std',
    'rf_10194010_roll6_std',
    'rf_10194010_roll12_median',
    'rf_10204010_roll6_std',
    'rf_10204020_roll12_std',
    'rf_10214030_roll6_std',
    'rf_10224010_roll12_std',
    'rf_10224020_roll6_std',
    'rf_10224020_roll12_std',
    'rf_10224040_roll12_std',
    'rf_10224050_roll12_std',
    'rf_10224060_roll12_std',
    'rf_10224070_roll6_std',
    'rf_10224090_roll12_std',
    'rf_10234020_roll6_std',
    'rf_10234020_roll12_std',
    'rf_10234030_roll6_std',
    'rf_10234040_roll12_std',
    'rf_11014010_roll6_std',
    'rf_11014010_roll12_std',
    'rf_11014020_roll12_std',
    'rf_11014040_roll6_std',
    'rf_11014060_roll6_std',
    'rf_11014100_roll6_std',
    'rf_11014120_s6',
    'rf_11014120_roll6_std',
    'rf_11014120_roll12_std',
    'yr',
    'tide_period_sin',
    'lunar_period_cos',
    'lunar_period_sin']

_useless_feature_names = [
    'fw_1018680', 'wl_1018645', 'fw_1018645', 'wl_1018655', 'fw_1018655', 
    'wl_1018660', 'fw_1018660', 'wl_1018664', 'fw_1018664', 'fw_1018669', 
    'wl_1018685', 'fw_1018685', 'fw_1007604', 'fw_1007642', 'fw_1007653', 
    'fw_1007656', 'fw_1007672', 'fw_1007697', 'wl_1018605', 'fw_1018605', 
    'wl_1018611', 'fw_1018611', 'wl_1018628', 'fw_1018628', 'fw_1018638', 
    'fw_1019667', 'fw_1022644', 'wl_1022659', 'fw_1022659', 'fw_1101609', 
    'wl_1022665', 'fw_1022665', 'fw_1101615', 'fw_1101625', 
    'wl_1101675', 'fw_1101675', 'wl_1101685', 'fw_1101685', 
    'wl_1101690', 'fw_1101690', 'wl_1202630', 'fw_1202630', 
    'wl_1202660', 'fw_1202660', 'wl_1202670', 'fw_1202670', 
    
    'fw_1007630', 'fw_1007634', 'fw_1007639', 'fw_1007649', 'fw_1007664',
    'wl_1015639', 'fw_1015680', 'fw_1019637', 'fw_1019675', 'wl_1021660',
    'fw_1021660', 'fw_1023640', 'fw_1023662', 'fw_1101696', 
    
    'wl_1007630', 'wl_1007649', 'wl_1013652', 'fw_1018623', 'fw_1022640',
    
]
_unimportant_feature_names = [
    'fw_1007620', 'fw_1007633', 'fw_1007641', 'fw_1007662', 'fw_1013620',
    'fw_1013652', 'fw_1015630', 'fw_1015639', 'fw_1015640', 'fw_1016655', 
    'fw_1016670', 'fw_1016695', 'fw_1017678', 'fw_1017690', 'fw_1018658', 
    'fw_1019620', 'fw_1019635', 'fw_1019636', 'fw_1019680', 'fw_1021670', 
    'fw_1022642', 'fw_1022643', 'fw_1022645', 'fw_1022662', 'fw_1022664', 
    'fw_1022666', 'fw_1022668', 'fw_1023680', 'fw_1101695', 'rf_10074020', 
    'rf_10154032', 'rf_10184030', 'rf_10184050', 'rf_10184070', 'rf_10184232', 
    'rf_10214020', 'rf_11014130', 'rf_11014140', 'rf_12024010', 'rf_12024020', 
    'wl_1007604', 'wl_1007642', 'wl_1007653', 'wl_1007656', 'wl_1007672', 
    'wl_1007697', 'wl_1017678', 'wl_1018638', 'wl_1018658', 'wl_1018669',
    'wl_1019636', 'wl_1019637', 'wl_1019667', 'wl_1019680', 'wl_1022642',
    'wl_1022643', 'wl_1022644', 'wl_1022645', 'wl_1022662', 'wl_1022664', 
    'wl_1022666', 'wl_1022668', 'wl_1101609', 'wl_1101615', 'wl_1101625'
]

# %%
_input_path = '../data'
# _input_path = '/data'

import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

def load_data(data_type):
    dataset_path = f'{_input_path}/{data_type}_data'
    dfs = []
    for file_name in sorted(os.listdir(f'{dataset_path}/')):
        if not file_name.endswith('.csv'):
            continue
        df = pd.read_csv(f'{dataset_path}/{file_name}', parse_dates=['ymdhm'])
        dfs.append( df )
    return pd.concat(dfs, axis=0, ignore_index=True)


def submit(Y_pred):
    '''
    Renders .csv file for submission.
    '''
    df = pd.read_csv(f'{_input_path}/sample_submission.csv')
    df['wl_1018662'] = Y_pred[:, 0]
    df['wl_1018680'] = Y_pred[:, 1]
    df['wl_1018683'] = Y_pred[:, 2]
    df['wl_1019630'] = Y_pred[:, 3]
    df.to_csv(f'../output/submission.csv', index=False)
    
def competition_metric(Y_true, Y_pred):
    '''
    Returns score for the current competition.
    '''
    l2_mean = np.mean(np.square(Y_true - Y_pred), axis=0)
    r_sq = 1 - (l2_mean / np.var(Y_true, axis=0))
    if np.isnan(r_sq).any() or (r_sq <= 0).any():
        return 999.
    return np.mean(np.sqrt(l2_mean) / r_sq)

# %%
def load_extended_data():
    wlobscds = ['1018662', '1018680', '1018683', '1019630']
    rfobscds = ['10184100', '10184110', '10184140']
    
    wlobscds += ['1018640', '1018645', '1018655', '1018658', '1018660', 
                '1018664', '1018669', '1018670', '1018675', '1018685',
                '1018695', '1018697']
    rfobscds += ['10184070', '10184080', '10184190', '10184200', '10194030']
    
    wlobscds += ['1007604', '1007605', '1007615', '1007617', '1007620', 
                 '1007625', '1007630', '1007633', '1007634', '1007635', 
                 '1007639', '1007640', '1007641', '1007642', '1007645', 
                 '1007649', '1007650', '1007653', '1007655', '1007656', 
                 '1007660', '1007662', '1007664', '1007672', '1007680', 
                 '1007685', '1007690', '1007697', '1013620', '1013652', 
                 '1013655', '1015630', '1015639', '1015640', '1015644', 
                 '1015645', '1015680', '1016607', '1016650', '1016655', 
                 '1016660', '1016670', '1016695', '1017678', '1017690', 
                 '1018605', '1018610', '1018611', '1018620', '1018623', 
                 '1018625', '1018628', '1018630', '1018635', '1018638', 
                 '1018650', '1018665', '1018690', '1018693', '1019620',
                 '1019635', '1019636', '1019637', '1019667', 
                 '1019675', '1019680', '1021650', '1021660', '1021670', 
                 '1021680', '1022640', '1022642', '1022643', '1022644', 
                 '1022645', '1022648', '1022650', '1022655', '1022659', 
                 '1022662', '1022664', '1022665', '1022666', '1022668', 
                 '1022670', '1022680', '1023640', '1023660', '1023662', 
                 '1023670', '1023680', '1101605', '1101609', '1101610', 
                 '1101615', '1101620', '1101625', '1101635', '1101645', 
                 '1101650', '1101663', '1101665', '1101670', '1101675', 
                 '1101680', '1101685', '1101690', '1101695', '1101696', 
                 '1202630', '1202660', '1202670']
    rfobscds += ['10064030', '10074010', '10074020', '10074030', '10074040', 
                 '10074060', '10074070', '10074080', '10074090', '10074100', 
                 '10074110', '10074120', '10074170', '10074175', '10134020', 
                 '10134030', '10134045', '10134140', '10154010', '10154020', 
                 '10154030', '10154032', '10154035', '10164010', '10164020', 
                 '10164030', '10164040', '10164050', '10164060', '10164070', 
                 '10164075', '10164080', '10174020', '10184010', '10184020', 
                 '10184030', '10184040', '10184050', '10184060', '10184090', 
                 '10184120', '10184125', '10184130', '10184150', 
                 '10184160', '10184170', '10184180', '10184210', '10184220', 
                 '10184230', '10184232', '10194010', '10204010', '10204020', 
                 '10214010', '10214020', '10214030', '10224010', '10224020', 
                 '10224040', '10224050', '10224060', '10224070', '10224090', 
                 '10234010', '10234020', '10234030', '10234040', '11014010', 
                 '11014020', '11014030', '11014040', '11014060', '11014070', 
                 '11014080', '11014090', '11014100', '11014120', '11014130', 
                 '11014140', '12024010', '12024020', ]
    
    obs_post_ids = ['DT_0032']
    obs_post_ids += ['DT_0044', 'DT_0058']

    date = 20220822
    df_dm = pd.read_csv(
        f'{_input_path}/OpenAPI_merged/dm_{date}.csv', 
        parse_dates=['ymdhm'], 
        na_values=[' ', '##########'])
    
    df_wl = []
    for wlobscd in wlobscds:
        if f'wl_{wlobscd}' in _useless_feature_names+_unimportant_feature_names and \
            f'fw_{wlobscd}' in _useless_feature_names+_unimportant_feature_names:
            continue
        df_wl.append( pd.read_csv(
            f'{_input_path}/OpenAPI_merged/wl_{wlobscd}_{date}.csv', 
            na_values=[' ', '##########'])
        )
    df_wl = pd.concat(df_wl, axis=1).drop(columns=['ymdhm'])

    df_rf = []
    for rfobscd in rfobscds:
        if f'rf_{rfobscd}' in _useless_feature_names+_unimportant_feature_names:
            continue
        df_rf.append( pd.read_csv(
            f'{_input_path}/OpenAPI_merged/rf_{rfobscd}_{date}.csv', 
            na_values=[' ', '##########']) 
                    )
    df_rf = pd.concat(df_rf, axis=1).drop(columns=['ymdhm'])

    df_tide = []
    for obs_post_id in obs_post_ids:
        if obs_post_id == 'DT_0058':
            continue
        df = pd.read_csv(f'{_input_path}/OpenAPI_merged/tide_level_{obs_post_id}_{date}.csv', parse_dates=['ymdhm'])
        df = df.drop_duplicates()
        df = df.set_index('ymdhm', drop=True)
        df = df.reindex(df.index.ceil('10min').drop_duplicates(), method='ffill')
        df = df.reindex(pd.date_range(pd.Timestamp(2012, 1, 1), pd.Timestamp(2022, 7, 31, 23, 50), freq='10min'))
        df = df.reset_index(drop=True)
        df_tide.append(df)
    df_tide = pd.concat(df_tide, axis=1)
    
    df = pd.concat([df_dm, df_wl, df_tide, df_rf], axis=1)
    df = df.drop(columns=list(set(_useless_feature_names + _unimportant_feature_names) & set(df.columns)))
    for name in df.columns:
        if name == 'ymdhm':
            continue
        df[name] = df[name].astype(np.float32)
    return df

# %%
def get_na_interval(ser, time=None):
    if time is None:
        time = ser.index
    begins = time[ser.isna().astype(int).diff() == 1]
    ends = time[ser.isna().astype(int).diff() == -1]
    if ser.isna().iloc[0]:
        ends = ends[1:]
    return begins, ends

def interpolate_linearly(ser, width=None):
    if width is None:
        width = np.inf
    values = np.sort(ser[ser.notna()].unique())
    begins, ends = get_na_interval(ser)
    for bi, ei in zip(begins, ends):
        if ei - bi > width:
            continue
        bv, ev = ser.loc[bi-1], ser.loc[ei]
        mvs = np.linspace(bv, ev, ei-bi+2)[1:-1]
        idx_l = np.searchsorted(values, mvs)
        idx_r = np.minimum(idx_l + 1, len(values)-1)
        l_is_closer = ((mvs - values[idx_l]) <= (values[idx_r] - mvs))
        mvs[l_is_closer] = values[idx_l[l_is_closer]]
        mvs[~l_is_closer] = values[idx_r[~l_is_closer]]
        ser.loc[bi:ei-1] = mvs
    return ser
        
def cleanup(df):
    time = df['ymdhm']
    
    for col_name in df.columns:
        if col_name.startswith('rf_'):
            df[col_name] = np.clip(df[col_name], 0, None)
    
#         ser = df[col_name]
#         if col_name == 'swl':
#             df.loc[ser <= 0, col_name] = np.nan
#             df.loc[ser >= 50, col_name] = np.nan
#             df.loc[time == pd.Timestamp(2016, 3, 5, 14, 50), col_name] = np.nan
#         elif col_name == 'inf':
#             df.loc[time.isin([
#                 pd.Timestamp(2013, 6, 5, 9, 50),
#                 pd.Timestamp(2015, 4, 28, 10, 30),
#                 pd.Timestamp(2016, 5, 23, 16, 10), 
#                 pd.Timestamp(2017, 12, 21, 5, 30), 
#                 pd.Timestamp(2017, 12, 21, 5, 40),
#                 pd.Timestamp(2018, 7, 5, 16, 40),
#                 pd.Timestamp(2021, 7, 9, 11, 40),
#             ]), col_name] = np.nan
#         elif col_name == 'sfw':
#             df.loc[ser == 0, col_name] = np.nan
#             df.loc[time.isin([
#                 pd.Timestamp(2016, 3, 5, 14, 50),
#                 pd.Timestamp(2016, 5, 17, 2),
#                 pd.Timestamp(2018, 7, 5, 16, 40)
#             ]), col_name] = np.nan
#         elif col_name == 'ecpc':
#             df.loc[ser == 244, col_name] = np.nan
#             df.loc[time.isin([
#                 pd.Timestamp(2016, 3, 5, 14, 50),
#                 pd.Timestamp(2016, 5, 17, 2),
#                 pd.Timestamp(2017, 12, 21, 5, 30), 
#                 pd.Timestamp(2017, 12, 21, 5, 40),
#                 pd.Timestamp(2018, 7, 5, 16, 40),
#             ]), col_name] = np.nan
#         elif col_name == 'tototf':
#             df.loc[time.isin([
#                 pd.Timestamp(2013, 6, 5, 9, 50),
#                 pd.Timestamp(2015, 4, 28, 10, 30),
#                 pd.Timestamp(2016, 5, 23, 16, 10), 
#                 pd.Timestamp(2021, 7, 9, 11, 40),
#             ]), col_name] = np.nan
        
    
#     for col_name, params in _eraser_params.items():
#         eraser = make_eraser(time, df[col_name], params)
#         df.loc[eraser, col_name] = np.nan
    
#     mask_unusual_spikes = (time >= pd.Timestamp(2017, 6, 20, 7)) & (time <= pd.Timestamp(2017, 6, 27, 17)) & (time.dt.minute == 0)
#     df.loc[mask_unusual_spikes, ['swl', 'inf', 'sfw', 'ecpc', 'tototf']] = np.nan
#     for col_name in df.columns:
#         df[col_name] = interpolate_linearly(df[col_name].copy())
#     mask_unusual_plateau = (time >= pd.Timestamp(2021, 10, 17)) & (time <= pd.Timestamp(2021, 10, 19, 15))
#     df.loc[mask_unusual_plateau, ['swl', 'inf', 'sfw', 'ecpc', 'tototf']] = np.nan
    
#     sfw, ecpc = rectify_sfw_ecpc(time, df['swl'], df['sfw'], df['ecpc'])
#     df['sfw'] = sfw
#     df['ecpc'] = ecpc
    return df

# %%
def features_for_learning(df):
    removed_features = ['ymdhm', 'fw_1018680']
    usable_features = [name for name in df.columns if name not in removed_features]
    time = df['ymdhm']
    result = dict()
    for name in usable_features:
#         for i in range(1, 12+1):
        for i in range(1, 6+1):
            result[f'{name}_s{i}'] = df[name].shift(i)
            result[f'{name}_diff1_s{i}'] = df[name].diff(1).shift(i)
            result[f'{name}_diff2_s{i}'] = df[name].diff(2).shift(i)
#         for i in [3, 6, 9, 12, 15, 18]:
        for i in [6, 12]:
            result[f'{name}_roll{i}_mean'] = df[name].rolling(i).agg('mean').shift(1)
            result[f'{name}_roll{i}_median'] = df[name].rolling(i).agg('median').shift(1)
            result[f'{name}_roll{i}_std'] = df[name].rolling(i).agg('std').shift(1)
#             result[f'{name}_roll{i}_max'] = df[name].rolling(i).agg('max').shift(1)
#             result[f'{name}_roll{i}_min'] = df[name].rolling(i).agg('min').shift(1)
#             result[f'{name}_absdiff_roll{i}_mean'] = np.abs(df[name].diff()).rolling(i).agg('mean').shift(1)
#             result[f'{name}_diff_roll{i}_sqmean'] = np.square(df[name].diff()).rolling(i).agg('mean').shift(1)
#             result[f'{name}_absdiff_roll{i}_max'] = np.abs(df[name].diff()).rolling(i).agg('max').shift(1)
#             result[f'{name}_absdiff_roll{i}_min'] = np.abs(df[name].diff()).rolling(i).agg('min').shift(1)
            
    result['yr'] = time.dt.year
#     result['month'] = time.dt.month
#     result['dow'] = time.dt.day_of_week
    
    elapsed_index = (time - time.iloc[0]).dt.total_seconds() // 600
    pi = np.pi
    
    _tide_period = 12 + 25/60
    _lunar_period = 29.53*24/2
    
    result['tide_period_cos'] = np.cos((2*pi/_tide_period)*elapsed_index)
    result['tide_period_sin'] = np.sin((2*pi/_tide_period)*elapsed_index)
    result['lunar_period_cos'] = np.cos((2*pi/_lunar_period)*elapsed_index)
    result['lunar_period_sin'] = np.sin((2*pi/_lunar_period)*elapsed_index)
#     result['tidal_clock'] = elapsed_index % _tide_period
#     result['lunar_clock'] = elapsed_index % _lunar_period
#     result['tide_2period_cos'] = np.cos((pi/_tide_period)*elapsed_index)
#     result['tide_2period_sin'] = np.sin((pi/_tide_period)*elapsed_index)
    
    result = pd.DataFrame(result)[sorted(set(_positive_importances) & set(result.keys()))]
    for name in result.columns:
        result[name] = result[name].astype(np.float32)
    return result

def labels_for_learning(df):
    return df[['wl_1018662', 'wl_1018680', 'wl_1018683', 'wl_1019630']]

# %%
df = load_extended_data()
df_old = pd.merge(load_data('water'), load_data('rf'), on='ymdhm')
df_old = df_old.set_index('ymdhm', drop=True)
df_old = df_old.reindex(pd.date_range(pd.Timestamp(2012, 1, 1), pd.Timestamp(2022, 7, 31, 23, 50), freq='10min'))
df_old = df_old.reset_index().rename(columns={'index': 'ymdhm'})
df = cleanup(df)

# %%
df_features = features_for_learning(df)
df_labels = labels_for_learning(df_old)
df_interms = labels_for_learning(df)

# %%
mask_train = (df['ymdhm'] < pd.Timestamp(2021, 6, 1))
mask_test = (df['ymdhm'] >= pd.Timestamp(2021, 6, 1)) & (df['ymdhm'] < pd.Timestamp(2021, 7, 19))
mask_train_final = (df['ymdhm'] < pd.Timestamp(2022, 6, 1))
mask_test_final = (df['ymdhm'] >= pd.Timestamp(2022, 6, 1)) & (df['ymdhm'] < pd.Timestamp(2022, 7, 19))

X_train, Y_train = df_features[mask_train], df_labels[mask_train]
X_test, Y_test = df_features[mask_test], df_labels[mask_test]

X_train_final, Y_train_final = df_features[mask_train_final], df_labels[mask_train_final]
X_test_final, _ = df_features[mask_test_final], _

I_train, I_test = df_interms[mask_train], df_interms[mask_test]
I_train_final = df_interms[mask_train_final]

# %%
import lightgbm as lgbm

class MyLGBM():
    def __init__(self, params):
        self.params = params
        
    def fit(self, X, Y):
        self.boosters = []
        for _, y in Y.iteritems():
            booster = lgbm.train(
                self.params,
                lgbm.Dataset(X, y),
            )
            self.boosters.append( booster )
        return self
    
    def predict(self, X):
        return np.stack([booster.predict(X) for booster in self.boosters], axis=1)

class Adapter():
    def __init__(self):
        pass
    
    def fit(self, X, Y):
        self.xs, self.ys = [], []
        for i in range(X.shape[1]):
            x, y = X.iloc[:, i], Y.iloc[:, i]
            x, y = x[~x.duplicated()], y[~x.duplicated()]
            mask_notna = ~np.isnan(x) & ~np.isnan(y)
            x, y = x[mask_notna], y[mask_notna]
            self.xs.append( x.iloc[x.argsort()] )
            self.ys.append( y.iloc[y.argsort()] )
        return self
    
    def transform(self, X):
        result = np.empty_like(X)
        for i in range(X.shape[1]):
            result[:, i] = np.interp(X[:, i], self.xs[i], self.ys[i])
        return result
            
params = {
    'max_depth': -1,
#     'num_leaves': 31,
#     'num_iterations': 100,
#     'learning_rate': 1e-1,
    'num_leaves': 48,
    'num_iterations': 364,
    'learning_rate': 9.641e-2,
    'force_row_wise': True,
    'random_state': 42,
    'deterministic': True,
    
    'verbosity': -1,
}

model = MyLGBM(params)
model.fit(X_train, I_train)

adapter = Adapter().fit(I_train, Y_train)
I_recon, I_pred = model.predict(X_train), model.predict(X_test)
Y_recon, Y_pred = adapter.transform(I_recon), adapter.transform(I_pred)
print(competition_metric(Y_train, Y_recon))
print(competition_metric(Y_test, Y_pred))

# 1.0774547811719222
# 0.9509602612761965
# Out:
# c:\users\sinwa\appdata\local\programs\python\python38\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# 0.8215447499112705
# 0.8001409238529582

# %%
_lower_features = []
for col_name in df_features.columns:
    use = False
    for name in df_old.columns:
        if name in col_name:
            use = True
#         elif 'tide' in name:
#             use = True
    if use:
        _lower_features.append( col_name )

XX_train = np.concatenate([X_train[_lower_features].values, Y_recon], axis=1)
XX_test = np.concatenate([X_test[_lower_features].values, Y_pred], axis=1)
lower_params = {
    'max_depth': -1,
#     'num_leaves': 31,
#     'num_iterations': 100,
#     'learning_rate': 1e-1,
    'num_leaves': 48,
    'num_iterations': 234,
    'learning_rate': 8.66621e-3,
    'force_row_wise': True,
    'random_state': 42,
    'deterministic': True,
    
    'verbosity': -1,
}
lower_model = MyLGBM(lower_params)
lower_model.fit(XX_train, pd.DataFrame(Y_train.values - Y_recon))
print(competition_metric(Y_train, Y_recon + lower_model.predict(XX_train)))
print(competition_metric(Y_test, Y_pred + lower_model.predict(XX_test)))
# Out:
# c:\users\sinwa\appdata\local\programs\python\python38\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# 0.8096651756348624
# 0.7966187467037728

# %%
model.fit(X_train_final, I_train_final)
adapter = Adapter().fit(I_train_final, Y_train_final)
Y_recon_final = adapter.transform(model.predict(X_train_final))
Y_pred_final = adapter.transform(model.predict(X_test_final))

XX_train_final = np.concatenate([X_train_final[_lower_features].values, Y_recon_final], axis=1)
XX_test_final = np.concatenate([X_test_final[_lower_features].values, Y_pred_final], axis=1)
lower_model.fit(XX_train_final, pd.DataFrame(Y_train_final.values - Y_recon_final))
submit(Y_pred_final + lower_model.predict(XX_test_final))
# Out:
# c:\users\sinwa\appdata\local\programs\python\python38\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")

# %%
Y_recon_final = adapter.transform(model.predict(X_train_final))
Y_pred_final = adapter.transform(model.predict(X_test_final))

XX_train_final = np.concatenate([X_train_final[_lower_features].values, Y_recon_final], axis=1)
XX_test_final = np.concatenate([X_test_final[_lower_features].values, Y_pred_final], axis=1)

YY_pred_final = Y_pred_final + lower_model.predict(XX_test_final)
competition_metric(adapter.transform(df_interms[mask_test_final].values), YY_pred_final)
# Out:
# 1.4952432884051192

# %%
plt.figure(figsize=(20, 8))
plt.plot(df['ymdhm'][mask_test_final], adapter.transform(df_interms[mask_test_final].values)[:, 0])
# plt.plot(df['ymdhm'][mask_test_final], YY_pred_final[:, 3])
plt.gca().twinx().plot(df['ymdhm'][mask_test_final], YY_pred_final[:, 0] - adapter.transform(df_interms[mask_test_final].values)[:, 0], color='C1')
plt.xlim(pd.Timestamp(2022, 6, 1), pd.Timestamp(2022, 6, 23))
plt.grid(); plt.show(); plt.close();

# %%
YY_pred = Y_pred + lower_model.predict(XX_test)

# %%
plt.figure(figsize=(20, 8))
plt.plot(df['ymdhm'][mask_test], Y_test.iloc[:, 0])
# plt.plot(df['ymdhm'][mask_test_final], YY_pred_final[:, 3])
plt.gca().twinx().plot(df['ymdhm'][mask_test], Y_pred[:, 0] - Y_test.iloc[:, 0], color='C1')
plt.xlim(pd.Timestamp(2021, 6, 1), pd.Timestamp(2021, 6, 23))
plt.ylim(-15, 23)
plt.grid(); plt.show(); plt.close();

# %%
# import tensorflow as tf
# from tensorflow import keras

# class LowerDNN(keras.Model):
#     def __init__(self, n_units, reg_coef):
#         super(LowerDNN, self).__init__()
#         self.fns = [
#             keras.layers.BatchNormalization(),
#             keras.layers.Dense(
#                 n_units[0],
#                 activation='elu',
#                 kernel_regularizer=keras.regularizers.l1(reg_coef)
#             )
#         ]
#         for n_unit in n_units[1:]:
#             self.fns.append( 
#                 keras.layers.BatchNormalization() 
#             )
#             self.fns.append( 
#                 keras.layers.Dense(
#                     n_unit,
#                     activation='elu',
#                     kernel_regularizer=keras.regularizers.l2(reg_coef)
#                 )
#             )
#         self.fns.append(
#             keras.layers.BatchNormalization()
#         )
#         self.fns.append(
#             keras.layers.Dense(
#                 4,
#                 kernel_regularizer=keras.regularizers.l2(reg_coef)
#             ),
#         )
    
#     def call(self, inputs):
#         outputs = inputs
#         for fn in self.fns:
#             outputs = fn(outputs)
#         return outputs
    
# keras.backend.clear_session()
# tf.random.set_seed(42)

# lower_model = LowerDNN(n_units=(64, 32), reg_coef=1e-3)
# lower_model.compile(
#     loss='mean_squared_error',
#     optimizer=keras.optimizers.Adam(5e-3),
#     metrics=['mean_squared_error']
# )
# callbacks = [keras.callbacks.EarlyStopping(
#     patience=50, restore_best_weights=True
# )]
